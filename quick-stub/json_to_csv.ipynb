# %%
import pandas as pd

# %%
df = pd.DataFrame(dct)

# %%
dct =  [{
 		"equipmentName": "FDF-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "Motor",
 		"componentInstance": 1,
 		"subcomponent": "Bearing",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "FDF-A MTR BRG TMP-DE",
 		"dataTagId": "spc_5e1b3384d42a8f17c4295675",
 		"componentName": "Motor",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e300edb63aa371106c5eb5f",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c4295675",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "DE",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "DE",
 		"subcomponentName": "Motor Bearing",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "FD Fan"
 	},
 	{
 		"equipmentName": "FDF-B",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Motor",
 		"componentInstance": 1,
 		"subcomponent": "Bearing",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 2,
 		"measureUnit": "-",
 		"description": "FDF-B MTR BRG TMP DE",
 		"dataTagId": "spc_5e1b3384d42a8f17c4295676",
 		"componentName": "Motor",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e300f4863aa371106c5eb60",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c4295676",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "DE",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "DE",
 		"subcomponentName": "Motor Bearing",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "FD Fan"
 	},
 	{
 		"equipmentName": "IDF-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "Control Damper",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "IDF-A IL CTRL DMPR",
 		"dataTagId": "spc_5e1b3383d42a8f17c429565e",
 		"componentName": "-",
 		"system": "Boiler",
 		"tagType": "Feedback",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e300fb163aa371106c5eb61",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429565e",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "Control Damper",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "ID Fan"
 	},
 	{
 		"equipmentName": "IDF-AB",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "VFD",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "4LSR01 IDF-4A (VFD TRF) CURB",
 		"dataTagId": "spc_5e1b3384d42a8f17c4295681",
 		"componentName": "VFD",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e30100763aa371106c5eb62",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c4295681",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "Phase",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "B-Phase",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "ID Fan"
 	},
 	{
 		"equipmentName": "IDF-B",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Fan",
 		"componentInstance": 1,
 		"subcomponent": "Bearing",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "IDF-B BRG TMP-DE",
 		"dataTagId": "spc_5e1b3383d42a8f17c429565f",
 		"componentName": "Fan",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e30105e63aa371106c5eb63",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429565f",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "DE",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "DE",
 		"subcomponentName": "Fan Bearing",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "ID Fan"
 	},
 	{
 		"equipmentName": "IDF-4B",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "VFD",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "4LSR02 IDF-4B (VFD TRF) CURR",
 		"dataTagId": "spc_5e1b3384d42a8f17c4295682",
 		"componentName": "VFD",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e3010ad63aa371106c5eb64",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c4295682",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "Phase",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "R-Phase",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "ID Fan"
 	},
 	{
 		"equipmentName": "PAF-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "Lubricating Oil Pump",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "PAF-B LOP A",
 		"dataTagId": "spc_5e1b3383d42a8f17c4295644",
 		"componentName": "LO Pump-A",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e3011e763aa371106c5eb65",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c4295644",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "PA Fan"
 	},
 	{
 		"equipmentName": "PAF-B",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "Lubricating Oil Pump",
 		"componentInstance": 2,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "PAF-B LOP B",
 		"dataTagId": "spc_5e1b3383d42a8f17c4295645",
 		"componentName": "LO Pump-B",
 		"system": "Boiler",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "PCFB",
 		"id": "5e30120163aa371106c5eb66",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c4295645",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "PA Fan"
 	},
 	{
 		"equipmentName": "CT Fan 04",
 		"equipmentType": "-",
 		"equipmentInstance": 4,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "CLG TWR FAN 04 CURRENT",
 		"dataTagId": "spc_5e1b3383d42a8f17c4295667",
 		"componentName": "-",
 		"system": "Cooling Water System",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "cooling tower",
 		"id": "5e30126663aa371106c5eb67",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c4295667",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "CT Fan"
 	},
 	{
 		"equipmentName": "CEP-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "CEP A RUN HOURS",
 		"dataTagId": "spc_5e1b3383d42a8f17c429563c",
 		"componentName": "-",
 		"system": "Condensate Cycle",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Condensate Cycle",
 		"id": "5e3012d463aa371106c5eb68",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429563c",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "CEP"
 	},
 	{
 		"equipmentName": "CEP-B",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "KW",
 		"description": "CEP B RUN HOURS",
 		"dataTagId": "spc_5e1b3383d42a8f17c429563d",
 		"componentName": "-",
 		"system": "Condensate Cycle",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Condensate Cycle",
 		"id": "5e30138a63aa371106c5eb69",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429563d",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "CEP"
 	},
 	{
 		"equipmentName": "CEP-1",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "Pump",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Consumption",
 		"measureInstance": 1,
 		"measureUnit": "KW",
 		"description": "\nCEP-1 DISCH PR",
 		"dataTagId": "pc_5e1b3384d42a8f17c429567e",
 		"componentName": "Pump",
 		"system": "Condensate Cycle",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Condensate Cycle",
 		"id": "5e301eb763aa371106c5eb6a",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c429567e",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "Outlet",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "Discharge",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "CEP"
 	},
 	{
 		"equipmentName": "CEP-2",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Pump",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Consumption",
 		"measureInstance": 1,
 		"measureUnit": "KW",
 		"description": "\nCEP-2 DISCH PR",
 		"dataTagId": "pc_5e1b3384d42a8f17c429567f",
 		"componentName": "Pump",
 		"system": "Condensate Cycle",
 		"tagType": "-",
 		"group": "Condensate Path",
 		"badDirection": "-",
 		"systemName": "Condensate Cycle",
 		"id": "5e301f4e63aa371106c5eb6b",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c429567f",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "Outlet",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "Discharge",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"Condensate Path"
 		],
 		"equipment": "CEP"
 	},
 	{
 		"equipmentName": "CEP-2",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Pump",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "\nCEP-2 DISCH PR",
 		"dataTagId": "spc_5e1b3384d42a8f17c429567f",
 		"componentName": "Pump",
 		"system": "Condensate Cycle",
 		"tagType": "-",
 		"group": "Condensate Path",
 		"badDirection": "-",
 		"systemName": "Condensate Cycle",
 		"id": "5e301f7e63aa371106c5eb6c",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c429567f",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "Outlet",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "Discharge",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"Condensate Path"
 		],
 		"equipment": "CEP"
 	},
 	{
 		"equipmentName": "CEP-1",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "Pump",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "\nCEP-1 DISCH PR",
 		"dataTagId": "spc_5e1b3384d42a8f17c429567e",
 		"componentName": "Pump",
 		"system": "Condensate Cycle",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Condensate Cycle",
 		"id": "5e301ffc63aa371106c5eb6d",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3384d42a8f17c429567e",
 		"measureLocationInstance": "1",
 		"LimRangeLo": -10000000000,
 		"measureLocation": "Outlet",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "Discharge",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "CEP"
 	},
 	{
 		"equipmentName": "Mill-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "\nPULV A ON FDBK",
 		"dataTagId": "spc_5e1b3383d42a8f17c4295658",
 		"componentName": "-",
 		"system": "Fuel Supply",
 		"tagType": "Feedback",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Fuel Supply",
 		"id": "5e3107f163aa371106c5eb6f",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c4295658",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "Pulverizer"
 	},
 	{
 		"equipmentName": "Mill-B",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Motor",
 		"componentInstance": 1,
 		"subcomponent": "Winding",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 2,
 		"measureUnit": "DegC",
 		"description": "MILL-B MTR WDG TMP-2",
 		"dataTagId": "spc_5e1b3383d42a8f17c4295659",
 		"componentName": "Mill Motor",
 		"system": "Fuel Supply",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Fuel Supply",
 		"id": "5e31085a63aa371106c5eb70",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c4295659",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "Motor Winding",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "Pulverizer"
 	},
 	{
 		"equipmentName": "Mill-E",
 		"equipmentType": "-",
 		"equipmentInstance": 5,
 		"component": "Lubricating Oil Tank",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "\nPULV E LUBE OIL LEVE",
 		"dataTagId": "spc_5e1b3383d42a8f17c429565c",
 		"componentName": "LO Tank",
 		"system": "Fuel Supply",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Fuel Supply",
 		"id": "5e3108c663aa371106c5eb71",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429565c",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "Pulverizer"
 	},
 	{
 		"equipmentName": "Mill-C",
 		"equipmentType": "-",
 		"equipmentInstance": 3,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "Cold Air Damper",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "CAD-C",
 		"dataTagId": "spc_5e1b3383d42a8f17c429565a",
 		"componentName": "-",
 		"system": "Fuel Supply",
 		"tagType": "Feedback",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Fuel Supply",
 		"id": "5e31092363aa371106c5eb72",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429565a",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "CAD",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "Pulverizer"
 	},
 	{
 		"equipmentName": "Mill-D",
 		"equipmentType": "-",
 		"equipmentInstance": 4,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "Cold Air Damper",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "CAD-D",
 		"dataTagId": "spc_5e1b3383d42a8f17c429565b",
 		"componentName": "-",
 		"system": "Fuel Supply",
 		"tagType": "Feedback",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "Fuel Supply",
 		"id": "5e310a1863aa371106c5eb73",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429565b",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "CAD",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "Pulverizer"
 	},
 	{
 		"equipmentName": "MDBFP-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Consumption",
 		"measureInstance": 1,
 		"measureUnit": "KW",
 		"description": "BFP A Run hours",
 		"dataTagId": "pc_5e1b3383d42a8f17c429563a",
 		"componentName": "-",
 		"system": "BFP System",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "BFP System",
 		"id": "5e328e5e63aa371106c5eb74",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429563a",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "MDBFP"
 	},
 	{
 		"equipmentName": "MDBFP-A",
 		"equipmentType": "-",
 		"equipmentInstance": 1,
 		"component": "-",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "BFP A Run hours",
 		"dataTagId": "spc_5e1b3383d42a8f17c429563a",
 		"componentName": "-",
 		"system": "BFP System",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "BFP System",
 		"id": "5e328e8563aa371106c5eb75",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429563a",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "MDBFP"
 	},
 	{
 		"equipmentName": "MDBFP-B",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Hydraulic Coupling",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Consumption",
 		"measureInstance": 1,
 		"measureUnit": "KW",
 		"description": "BFP B",
 		"dataTagId": "pc_5e1b3383d42a8f17c429563b",
 		"componentName": "Hydraulic Coupling",
 		"system": "BFP System",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "BFP System",
 		"id": "5e328efc63aa371106c5eb76",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429563b",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "MDBFP"
 	},
 	{
 		"equipmentName": "MDBFP-B",
 		"equipmentType": "-",
 		"equipmentInstance": 2,
 		"component": "Hydraulic Coupling",
 		"componentInstance": 1,
 		"subcomponent": "-",
 		"subcomponentInstance": 1,
 		"measureProperty": "Power",
 		"measureType": "Specific",
 		"measureInstance": 1,
 		"measureUnit": "-",
 		"description": "BFP B",
 		"dataTagId": "spc_5e1b3383d42a8f17c429563b",
 		"componentName": "Hydraulic Coupling",
 		"system": "BFP System",
 		"tagType": "-",
 		"group": "-",
 		"badDirection": "-",
 		"systemName": "BFP System",
 		"id": "5e328f2563aa371106c5eb77",
 		"unitsId": "5df8f5a57e961b7f0bccc7ed",
 		"equipmentId": "5e1b3383d42a8f17c429563b",
 		"measureLocationInstance": 1,
 		"LimRangeLo": -10000000000,
 		"measureLocation": "-",
 		"siteId": "5df8f5417e961b7f0bccc7ec",
 		"measureLocationName": "-",
 		"subcomponentName": "-",
 		"LimRangeHi": 10000000000,
 		"customerId": "5c4ed3c4fe02914642b4d5ba",
 		"groupList": [
 			"-"
 		],
 		"equipment": "MDBFP"
 	}
 ]

# %%
df.to_csv("add_tags.csv",index=False)
